# %%
from datasets import load_dataset

# %%
dataset = load_dataset("ContributorsSIGNAL/SIGNAL")

# %%
dataset["train"].to_pandas()["sentence"].unique()
# Out:
# array(['Автобусы проходят массовую дезинфекцией',
#        'Автобусы проходят массовую дезинфекцию',
#        'Автобусы проходят массовую фортуной',
#        'Автобусы проходят массовую фортуну', 'Авторы получали подарками',
#        'Авторы получали подарки', 'Авторы получали районах',
#        'Авторы получали районы', 'Авторы получат призах',
#        'Авторы получат призы', 'Авторы получат пунктах',
#        'Авторы получат пункты', 'Адвокат обжаловал воспоминание властей',
#        'Адвокат обжаловал воспоминанием властей',
#        'Адвокат обжаловал решение властей',
#        'Адвокат обжаловал решением властей',
#        'Администратор нажала кнопке сигнализации',
#        'Администратор нажала кнопку сигнализации',
#        'Администратор нажала родиной сигнализации',
#        'Администратор нажала родину сигнализации',
#        'Администрация начала спасательную культуре',
#        'Администрация начала спасательную культуру',
# ...
